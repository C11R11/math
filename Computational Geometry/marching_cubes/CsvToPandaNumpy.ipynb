# %% [markdown]
# # Pandas to arrays
#
# https://pythonguides.com/convert-pandas-dataframe-to-numpy-array/

# %%
import pandas as pd

# %%
csv = "ext_array.csv"
df = pd.read_csv(csv)
df.head()
# Out:
#    5.000000  5.000000.1  595.000000
# 0      15.0         5.0       595.0
# 1       5.0        15.0       595.0
# 2      25.0         5.0       595.0
# 3      35.0         5.0       595.0
# 4      45.0         5.0       595.0

# %%
df.describe()
# Out:
#            5.000000    5.000000.1    595.000000
# count  45245.000000  45245.000000  45245.000000
# mean     360.784507    402.265554    780.555752
# std      265.690329    272.467989    114.513666
# min        5.000000      5.000000    585.000000
# 25%      115.000000    155.000000    685.000000
# 50%      345.000000    395.000000    765.000000
# 75%      595.000000    635.000000    855.000000
# max      835.000000    845.000000   1045.000000

# %%
x = df.to_numpy()

# %%
x.shape, x.size, x.ndim
# Out:
# ((45245, 3), 135735, 2)

# %%
x = df.to_numpy()

# %%
xx = x[:,0]
yy = x[:,1]
zz = x[:,2]

b = np.reshape(x, (45245, 3, -1))

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
plt.plot(x[:,0],x[:,1],x[:,2], ",",  alpha=1)

ax.view_init(45, 30)
plt.show()

# %%
from scipy.spatial import ConvexHull

hull = ConvexHull(x)
indices = hull.simplices
vertices = x[indices]
vertices
# Out:
# array([[[  95.,  135.,  585.],
#         [ 505.,    5.,  605.],
#         [ 505.,   35.,  605.]],
#
#        [[ 315.,  845.,  695.],
#         [ 605.,  845.,  725.],
#         [ 165.,  655.,  635.]],
#
#        [[  95.,  595.,  625.],
#         [   5.,  665.,  645.],
#         [   5.,  545.,  625.]],
#
#        ...,
#
#        [[ 185.,  175., 1035.],
#         [ 215.,  205., 1035.],
#         [ 235.,  195., 1025.]],
#
#        [[ 185.,  175., 1035.],
#         [  85.,   85., 1035.],
#         [ 105.,   75., 1025.]],
#
#        [[ 185.,  175., 1035.],
#         [ 105.,   75., 1025.],
#         [ 205.,  165., 1025.]]])

# %%
type(vertices), vertices.shape, vertices.flatten()
# Out:
# (numpy.ndarray,
#  (136, 3, 3),
#  array([  95.,  135.,  585., ...,  205.,  165., 1025.]))

# %%
faces[0]
# Out:
# array([2, 1, 0])

# %%
face = a3.art3d.Poly3DCollection([faces[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26612\4184096069.py in <module>
# ----> 1 face = a3.art3d.Poly3DCollection(faces[0])
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in __init__(self, verts, zsort, *args, **kwargs)
#     714         and _edgecolors properties.
#     715         """
# --> 716         super().__init__(verts, *args, **kwargs)
#     717         if isinstance(verts, np.ndarray):
#     718             if verts.ndim != 3:
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, verts, sizes, closed, **kwargs)
#    1186         super().__init__(**kwargs)
#    1187         self.set_sizes(sizes)
# -> 1188         self.set_verts(verts, closed)
#    1189         self.stale = True
#    1190
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in set_verts(self, verts, closed)
#     758     def set_verts(self, verts, closed=True):
#     759         """Set 3D vertices."""
# --> 760         self.get_vector(verts)
#     761         # 2D verts will be updated at draw time
#     762         super().set_verts([], False)
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in get_vector(self, segments3d)
#     747         """Optimize points for projection."""
#     748         if len(segments3d):
# --> 749             xs, ys, zs = np.row_stack(segments3d).T
#     750         else:  # row_stack can't stack zero arrays.
#     751             xs, ys, zs = [], [], []
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
indices

# %%
import mpl_toolkits.mplot3d as a3

for f in faces:
    face = a3.art3d.Poly3DCollection([f])
    face.set_color(mpl.colors.rgb2hex(sp.rand(3)))
    face.set_edgecolor('k')
    face.set_alpha(0.5)
    ax.add_collection3d(face)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26612\1888893064.py in <module>
#       2
#       3 for f in faces:
# ----> 4     face = a3.art3d.Poly3DCollection([f])
#       5     face.set_color(mpl.colors.rgb2hex(sp.rand(3)))
#       6     face.set_edgecolor('k')
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py in __init__(self, verts, zsort, *args, **kwargs)
#     720         else:
#     721             if any(len(np.shape(vert)) != 2 for vert in verts):
# --> 722                 raise ValueError('verts must be a list of (N, 3) array-like')
#     723         self.set_zsort(zsort)
#     724         self._codes3d = None
#
# ValueError: verts must be a list of (N, 3) array-like
