# %%
import numpy as np
import mcubes
import open3d as o3d
import matplotlib.pyplot as plt

# %%
np.mgrid[:10, :10, :10]

# %%
x = np.zeros([4,4,4])
x = x + 99

x[1:3,1:3,1] = -0.12
x[1:3,1:3,3] = -0.12
x[1,1:3,1:3] = -0.12
x[3,1:3,1:3] = -0.12
x[1:3,1,1:3] = -0.12
x[1:3,3,1:3] = -0.12
#x[4][4] = -0.12

print(x[:,0], x[:,1], x[:,2])

plt.contourf(x[:,0],x[:,1],x[:,2],levels=20)

import numpy as np
# Extract the 0-isosurface
vertices, triangles = mcubes.marching_cubes(x, 0)

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
plt.plot(vertices[:,0],vertices[:,1],vertices[:,2], "o",  alpha=1)
#ax.axes.set_xlim3d(left=-10, right=10) 
#ax.axes.set_xlim3d(left=int(np.amin(u[:,0])), right=int(np.amax(u[:,0]))) 
#ax.axes.set_ylim3d(bottom=int(np.amin(u[:,1])), top=int(np.amax(u[:,1]))) 
#ax.axes.set_zlim3d(bottom=int(np.amin(u[:,2])), top=int(np.amax(u[:,2]))) 
plt.show()

mcubes.export_obj(vertices, triangles, 'mcubes.obj')

mesh = o3d.io.read_triangle_mesh("mcubes.obj")
o3d.visualization.draw_geometries([mesh], mesh_show_wireframe=True)
# Out:
# [[99. 99. 99. 99.]
#  [99. 99. 99. 99.]
#  [99. 99. 99. 99.]
#  [99. 99. 99. 99.]] [[99.   99.   99.   99.  ]
#  [99.   -0.12 -0.12 -0.12]
#  [99.   -0.12 -0.12 -0.12]
#  [99.   -0.12 -0.12 99.  ]] [[99.   99.   99.   99.  ]
#  [99.   -0.12 -0.12 -0.12]
#  [99.   -0.12 99.   -0.12]
#  [99.   -0.12 -0.12 99.  ]]

# %%
# Create a data volume (30 x 30 x 30)
w = 8
v = w/2
c = w/3
i = v

print(f"w = {w} v = {v} c = {c} i={i}")

X, Y, Z = np.mgrid[:w, :w, :w]
u = (X-v)**2 + (Y-v)**2 + (Z-v)**2 - 8
#u = (X-v)+(Y-v)+(Z-v)-c
#u = X + Y + Z
#u = np.ones((20,20,20))

print(X.shape, X.ndim, X.size)
print(np.amin(u[:,0]), np.amax(u[:,0]), u)

# %%
u[6][6][4], vertices

# %%
import numpy as np
# Extract the 0-isosurface
vertices, triangles = mcubes.marching_cubes(u, .5)

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
plt.plot(vertices[:,0],vertices[:,1],vertices[:,2], "o",  alpha=1)
#ax.axes.set_xlim3d(left=-10, right=10) 
#ax.axes.set_xlim3d(left=int(np.amin(u[:,0])), right=int(np.amax(u[:,0]))) 
#ax.axes.set_ylim3d(bottom=int(np.amin(u[:,1])), top=int(np.amax(u[:,1]))) 
#ax.axes.set_zlim3d(bottom=int(np.amin(u[:,2])), top=int(np.amax(u[:,2]))) 
plt.show()

mcubes.export_obj(vertices, triangles, 'mcubes.obj')

mesh = o3d.io.read_triangle_mesh("mcubes.obj")
o3d.visualization.draw_geometries([mesh], mesh_show_wireframe=True)

# %%
X

# %%
o =

# %%
o.sort()

# %%
o

# %%
X.sort()

# %%
X

# %%
u.shape, u.size, u.ndim, u

# %%
plt.contourf(X,Y,Z, levels=30)
plt.colorbar()

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
plt.plot(u[:,0], u[:,1], u[:,2])
plt.show()

# %%
f.shape, f.size, f.ndim, f

# %%
vertices, triangles

# %%
mcubes.export_obj(vertices, triangles, 'mcubes.obj')

# %%
mcubes.export_obj(vertices, triangles, 'mcubes.obj')

mesh = o3d.io.read_triangle_mesh("mcubes.obj")
o3d.visualization.draw_geometries([mesh], mesh_show_wireframe=True)

# %%
# plotting
#x=np.linspace(-5,5,11)
#y=np.linspace(-5,5,11)

#x, y = np.mgrid[:30, :30,]
#Z= X**2+Y**2

X, Y  = np.mgrid[:10, :10]
Z = np.ones((10,10))
u = (X+2)**2 + (Y+2)**2 + Z**2 

print(Z.ndim)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, u, cmap="plasma", linewidth=0, antialiased=False, alpha=0.5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
# rotation
ax.view_init(45,70)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z)

# Set an equal aspect ratio
ax.set_aspect('auto')

plt.show()

# %%
x, x.shape, x.ndim

# %%
len(u), u.shape, u.ndim, u

# %%
np.ones(np.size(u)), np.size(u), np.cos(v)

# %%
X, Y, Z = np.mgrid[:30, :30, :30]

# %%
X.shape, X.size, X.ndim

# %%
only_x = X.reshape(1,-1,3)

# %%
only_x

# %%
X = np.mgrid[:5, :5]
Y = np.mgrid[:5, :5]
Z = np.mgrid[:5, :5]
xx, yy, zz = np.meshgrid(X,Y,Z)
print(xx.shape, yy.shape, zz.shape)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xx, yy, zz)
#ax.set_zlim(12, 15)
plt.show()

# %%
  import numpy as np
  import mcubes

  # Create a data volume (30 x 30 x 30)
  X, Y, Z = np.mgrid[:30, :30, :30]
  u = (X-15)**2 + (Y-15)**2 + (Z-15)**2 - 8**2

  # Extract the 0-isosurface
  #vertices, triangles = mcubes.marching_cubes(u, 0)

  # Export the result to sphere.dae
  #mcubes.export_mesh(vertices, triangles, "sphere.dae", "MySphere")

# %%
u[0,0,0]

# %%
# Import libraries
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
 
 
# Create axis
axes = [5, 5, 5]
 
# Create Data
data = np.ones(axes, dtype=int)

print(data.shape, data.size, data)
 
# Control Transparency
alpha = 0.9
 
# Control colour
colors = np.empty(axes + [4], dtype=np.float32)
 
colors[:] = [1, 0, 0, alpha]  # red
 
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Voxels is used to customizations of the
# sizes, positions and colors.
ax.voxels(data, facecolors=colors)

# %%
import numpy as np

a = np.zeros([3,3])

X = np.mgrid[:10, :10, :10]
Y = np.mgrid[:3, :3]
Z = np.mgrid[:3, :3]

# %%
a = np.zeros([3,3])

# %%
a

# %%
X, X.shape, X.size, X.ndim

# %%
xx, yy, zz = np.meshgrid(X,Y,Z)
print(xx.shape, yy.shape, zz.shape)

# %%
meshg = np.mgrid[0:30, 0:30]

# %%
a = np.array(np.meshgrid(np.linspace(0,2,3),np.linspace(0,2,3)))

# %%
a.shape, a.size, a.ndim, a
