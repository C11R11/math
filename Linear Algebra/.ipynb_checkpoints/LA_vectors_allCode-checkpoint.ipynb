# %% [markdown]
# #     COURSE: Linear algebra: theory and implementation
# ##    SECTION: Vectors
#
# #### Instructor: sincxpress.com
# ##### Course url: https://www.udemy.com/course/linear-algebra-theory-and-implementation/?couponCode=202110

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# # VIDEO: Algebraic and geometric interpretations
# ---

# %%
# 2-dimensional vector
v2 = [ 3, -2 ]

v2n = np.array(v2)
print(v2n, v2n.shape, v2n.T)

# 3-dimensional vector
v3 = [ 4, -3, 2 ]

# row to column (or vice-versa):
v3t = np.transpose(v3)
print(v3t)

# plot them
plt.plot([0,v2[0]],[0,v2[1]])
plt.axis('equal')
plt.plot([-4, 4],[0, 0],'k--')
plt.plot([0, 0],[-4, 4],'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()


# plot the 3D vector
fig = plt.figure(figsize=plt.figaspect(1))
# ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')
ax.plot([0, v3[0]],[0, v3[1]],[0, v3[2]],linewidth=3)

# make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4],'k--')
ax.plot([0, 0],[-4, 4],[0, 0],'k--')
ax.plot([-4, 4],[0, 0],[0, 0],'k--')
plt.show()
# Out:
# [ 3 -2] (2,) [ 3 -2]
# [ 4 -3  2]

# %% [markdown]
# ---
# # VIDEO: Vector addition/subtraction
# ---

# %%
# two vectors in R2
v1 = np.array([ 3, 1 ])
v2 = np.array([ 2,  1 ])

v3 = v1 + v2
print(v3)


# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
#plt.plot([0, v2[0]],[0, v2[1]],'b',label='v1')
plt.plot([0, v2[0]]+v1[0],[0, v2[1]]+v1[1],'r',label='v2')
plt.plot([0, v3[0]],[0, v3[1]],'k',label='v1+v2')

plt.legend()
plt.axis('square')
plt.axis((-1, 6, -1, 3))
plt.grid()
plt.show()
# Out:
# [5 2]

# %%
# two vectors in R2
v1 = np.array([ 3, 1 ])
v2 = np.array([ 2,  1 ])

v3 = v1 - v2
print(v3)


# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
plt.plot([0, v2[0]],[0, v2[1]],'b',label='v1')
plt.plot([0, v2[0]],[0, v3[1]],'k',label='v1-v2')

plt.legend()
plt.axis('square')
plt.axis((-1, 6, -1, 3))
plt.grid()
plt.show()
# Out:
# [1 0]

# %% [markdown]
# ---
# # VIDEO: Vector-scalar multiplication
# ---

# %%
# vector and scalar
v1 = np.array([ 3, -1 ])
l  = -.4
v1m = v1*l # scalar-modulated

# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='$v_1$')
plt.plot([0, v1m[0]],[0, v1m[1]],'r:',label='$\lambda v_1$')

plt.legend()
plt.axis('square')
axlim = max([max(abs(v1)),max(abs(v1m))])*1.2 # dynamic axis lim
plt.axis((-axlim,axlim,-axlim,axlim))
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # vector and scalar
# ----> 2 v1 = np.array([ 3, -1 ])
#       3 l  = -.4
#       4 v1m = v1*l # scalar-modulated
#
# NameError: name 'np' is not defined

# %% [markdown]
# ---
# # VIDEO: Vector-vector multiplication: the dot product
# ---

# %%
## many ways to compute the dot product

v1 = np.array([ 1, 2, 3, 4, 5, 6 ])
v2 = np.array([ 0, -4,  2, -3, 6, 5 ])

# method 1
dp1 = sum( np.multiply(v1,v2) )

# method 2
dp2 = np.dot( v1,v2 )

# method 3
dp3 = np.matmul( v1,v2 )

# method 4
dp4 = 0  # initialize

# loop over elements
for i in range(len(v1)):

    # multiply corresponding element and sum
    dp4 = dp4 + v1[i]*v2[i]


print(dp1,dp2,dp3,dp4)
# Out:
# 46 46 46 46

# %% [markdown]
# # Exercise

# %%
import numpy as np

a = np.array([1, -2])
b = np.array([2, 3])
c = np.array([0, 2])

print(a.dot(b), a.dot(c), b.dot(a), b.dot(c), c.dot(b))
# Out:
# -4 -4 -4 6 6

# %% [markdown]
# # VIDEO: Dot product properties: associative and distributive

# %%
## Distributive property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , (b+c) )
res2 = np.dot(a,b) + np.dot(a,c)

# compare them
print([ res1,res2 ])

# %%
## Associative property

# create random vectors
n = 5
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , np.dot(b,c) )
res2 = np.dot( np.dot(a,b) , c )

# compare them
print(res1)
print(res2)


### special cases where associative property works!
# 1) one vector is the zeros vector
# 2) a==b==c

# %% [markdown]
# ---
# # VIDEO: Vector length
# ---

# %%
# a vector
v1 = np.array([ 1, 2, 3, 4, 5, 6 ])

# methods 1-4, just like with the regular dot product, e.g.:
vl1 = np.sqrt( sum( np.multiply(v1,v1)) )

# method 5: take the norm
vl2 = np.linalg.norm(v1)

print(vl1,vl2)

# %% [markdown]
# ---
# # VIDEO: The dot product from a geometric perspective
# ---

# %%
# two vectors
v1 = np.array([ 16,  -2, 4 ])
v2 = np.array([ .5, 2, -1 ])

# compute the angle (radians) between two vectors
ang = np.arccos( np.dot(v1,v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)) )
deg = ang * 180 / np.pi
print(deg)

# draw them
fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'b')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'r')

#plt.axis((-6, 6, -6, 6))
plt.title('Angle between vectors: %s rad.' %ang)
plt.show()
# Out:
# 90.0

# %%
## equivalence of algebraic and geometric dot product formulas

# two vectors
v1 = np.array([ 16,  -2, 4 ])
v2 = np.array([ .5, 2, 1 ])


# algebraic
dp_a = np.dot( v1,v2 )

# geometric
dp_g = np.linalg.norm(v1)*np.linalg.norm(v2)*np.cos(ang)

# print dot product to command
print(dp_a)
print(dp_g)
# Out:
# 8.0
# -4.99827556470125

# %% [markdown]
# ---
# # VIDEO: Vector Hadamard multiplication
# ---

# %%
# create vectors
w1 = [ 1, 3, 5 ]
w2 = [ 3, 4, 2 ]

w3 = np.multiply(w1,w2)
print(w3)

# %% [markdown]
# ---
# # VIDEO: Vector outer product
# ---

# %%
v1 = np.array([  1, 2, 3 ])
v2 = np.array([ -1, 0, 1 ])

# outer product
np.outer(v1,v2)

# terrible programming, but helps conceptually:
op = np.zeros((len(v1),len(v2)))
for i in range(0,len(v1)):
    for j in range(0,len(v2)):
        op[i,j] = v1[i] * v2[j]

print(op)

# %% [markdown]
# ---
# # VIDEO: Vector cross product
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# create vectors
v1  = [ -3,  2, 5 ]
v2  = [  4, -3, 0 ]

# Python's cross-product function
v3a = np.cross( v1,v2 )
print(v3a)

# "manual" method
v3b = [ [v1[1]*v2[2] - v1[2]*v2[1]],
        [v1[2]*v2[0] - v1[0]*v2[2]],
        [v1[0]*v2[1] - v1[1]*v2[0]] ]

print(v3a, type(v3a), v3a.shape)
print(v3b, type(v3b))


fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')

# draw plane defined by span of v1 and v2
xx, yy = np.meshgrid(np.linspace(-10,10,30),np.linspace(-10,10,30))
z1 = (-v3a[0]*xx - v3a[1]*yy)/v3a[2]
#print(xx, yy)
print(z1)
ax.plot_surface(xx,yy,z1)

## plot the two vectors
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'k')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'k')
ax.plot([0, v3a[0]],[0, v3a[1]],[0, v3a[2]],'r')


ax.view_init(azim=150,elev=45)
plt.show()
# Out:
# [15 20  
#    -84.48275862  -94.82758621 -105.17241379 -115.51724138 -125.86206897
#   -136.20689655 -146.55172414 -156.89655172 -167.24137931 -177.5862069
#   -187.93103448 -198.27586207 -208.62068966 -218.96551724 -229.31034483
#   -239.65517241 -250.         -260.34482759 -270.68965517 -281.03448276]
#  [   5.17241379   -5.17241379  -15.51724138  -25.86206897  -36.20689655
#    -46.55172414  -56.89655172  -67.24137931  -77.5862069   -87.93103448
#    -98.27586207 -108.62068966 -118.96551724 -129.31034483 -139.65517241
#   -150.         -160.34482759 -170.68965517 -181.03448276 -191.37931034
#   -201.72413793 -212.06896552 -222.4137931  -232.75862069 -243.10344828
#   -253.44827586 -263.79310345 -274.13793103 -284.48275862 -294.82758621]
#  [  -8.62068966  -18.96551724  -29.31034483  -39.65517241  -50.
#    -60.34482759  -70.68965517  -81.03448276  -91.37931034 -101.72413793
#   -112.06896552 -122.4137931  -132.75862069 -143.10344828 -153.44827586
#   -163.79310345 -174.13793103 -184.48275862 -194.82758621 -205.17241379
#   -215.51724138 -225.86206897 -236.20689655 -246.55172414 -256.89655172
#   -267.24137931 -277.5862069  -287.93103448 -298.27586207 -308.62068966]
#  [ -22.4137931   -32.75862069  -43.10344828  -53.44827586  -63.79310345
#    -74.13793103  -84.48275862  -94.82758621 -105.17241379 -115.51724138
#   -125.86206897 -136.20689655 -146.55172414 -156.89655172 -167.24137931
#   -177.5862069  -187.93103448 -198.27586207 -208.62068966 -218.96551724
#   -229.31034483 -239.65517241 -250.         -260.34482759 -270.68965517
#   -281.03448276 -291.37931034 -301.72413793 -312.06896552 -322.4137931 ]
#  [ -36.20689655  -46.55172414  -56.89655172  -67.24137931  -77.5862069
#    -87.93103448  -98.27586207 -108.62068966 -118.96551724 -129.31034483
#   -139.65517241 -150.         -160.34482759 -170.68965517 -181.03448276
#   -191.37931034 -201.72413793 -212.06896552 -222.4137931  -232.75862069
#   -243.10344828 -253.44827586 -263.79310345 -274.13793103 -284.48275862
#   -294.82758621 -305.17241379 -315.51724138 -325.86206897 -336.20689655]
#  [ -50.          -60.34482759  -70.68965517  -81.03448276  -91.37931034
#   -101.72413793 -112.06896552 -122.4137931  -132.75862069 -143.10344828
#   -153.44827586 -163.79310345 -174.13793103 -184.48275862 -194.82758621
#   -205.17241379 -215.51724138 -225.86206897 -236.20689655 -246.55172414
#   -256.89655172 -267.24137931 -277.5862069  -287.93103448 -298.27586207
#   -308.62068966 -318.96551724 -329.31034483 -339.65517241 -350.        ]]

# %% [markdown]
# ---
# # VIDEO: Hermitian transpose (a.k.a. conjugate transpose)
# ---

# %%
# create a complex number
z = complex(3,4)

# magnitude
print( np.linalg.norm(z) )

# by transpose?
print( np.transpose(z)*z )

# by Hermitian transpose
print( np.transpose(z.conjugate())*z )


# complex vector
v = np.array( [ 3, 4j, 5+2j, complex(2,-5) ] )
print( v.T )
print( np.transpose(v) )
print( np.transpose(v.conjugate()) )
# Out:
# 5.0
# (-7+24j)
# (25+0j)
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.-0.j 0.-4.j 5.-2.j 2.+5.j]

# %% [markdown]
# ---
# # VIDEO: Unit vector
# ---

# %%
# vector
v1 = np.array([ -3, 6 ])

# mu
mu = 1/np.linalg.norm(v1)
print(mu)

v1n = v1*mu

# plot them
plt.plot([0, v1n[0]],[0, v1n[1]],'r',label='v1-norm',linewidth=5)
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')

# axis square
plt.axis('square')
plt.axis(( -6, 6, -6, 6 ))
plt.grid()
plt.legend()
plt.show()
# Out:
# 0.14907119849998599

# %% [markdown]
# ---
# # VIDEO: Span
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# set S
S1 = np.array([1, 1, 0])
S2 = np.array([1, 7, 0])

# vectors v and w
v = np.array([1, 2, 0])
w = np.array([3, 2, 1])

# draw vectors
fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
ax = plt.axes(projection = '3d')
ax.plot([0, S1[0]],[0, S1[1]],[.1, S1[2]+.1],'r',linewidth=3)
ax.plot([0, S2[0]],[0, S2[1]],[.1, S2[2]+.1],'r',linewidth=3)

ax.plot([0, v[0]],[0, v[1]],[.1, v[2]+.1],'g',linewidth=3)
ax.plot([0, w[0]],[0, w[1]],[0, w[2]],'b')

# now draw plane
xx, yy = np.meshgrid(range(-15,16), range(-15,16))
cp = np.cross(S1,S2)
z1 = (-cp[0]*xx - cp[1]*yy)*1./cp[2]
ax.plot_surface(xx,yy,z1)

plt.show()
