# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.randint(0, 5, size=[3,3])

print(A)

plt.imshow(A, cmap='seismic')
plt.colorbar(fraction = 0.09, pad=0.04, orientation = 'vertical')
plt.show()
# Out:
# [[0 0 3]
#  [4 4 1]
#  [3 0 0]]
