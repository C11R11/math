# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.random.rand(1999)
y.shape, y

plt.plot(y, label="Original dataset")

Y = np.fft.fft(y)
print(Y)

np.put(Y, range(0, 1), 0.0)
np.put(Y, range(1+1, len(y)), 0.0)

ifft = np.fft.ifft(Y) # the sinusoid you're looking for

ifft
# Out:
# [ 9.90235802e+02+3.99680289e-15j  1.77639722e+01+3.18142196e+00j
#  -5.11715484e-01-1.05327500e+01j ... -1.49963708e+01+1.87224201e+01j
#  -5.11715484e-01+1.05327500e+01j  1.77639722e+01-3.18142196e+00j]
# array([0.00888643+0.00159151j, 0.00888138+0.00161943j,
#        0.00887625+0.00164734j, ..., 0.00890104+0.00150764j,
#        0.00889626+0.00153561j, 0.00889139+0.00156357j])

# %%
n = len(y)
Y = np.fft.fft(y)
numpy.put(Y, range(0, i), 0.0)
numpy.put(Y, range(i+1, n), 0.0)
# Now Y holds 1 imaginary coefficient corresponding with the i-eth Fourier component
